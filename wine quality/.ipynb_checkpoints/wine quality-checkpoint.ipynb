# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv("DATA/winequality-red.csv",delimiter=";")
white_wine = pd.read_csv("DATA/winequality-white.csv",delimiter=";")

# %%
red_wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white_wine.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %%
red_wine["Color"] = "R"
white_wine["Color"] = "W"
data = pd.concat([red_wine,white_wine],axis=0)

# %%
data.tail(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality Color
# 4893     11.2        6     W
# 4894      9.6        5     W
# 4895      9.4        6     W
# 4896     12.8        7     W
# 4897     11.8        6     W

# %%
df = pd.get_dummies(data, columns=["Color"])

# %%
data.isnull().any()
# Out:
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# Color                   False
# dtype: bool

# %%
red_wine["quality"].mean()
# Out:
# 5.6360225140712945

# %%
white_wine["quality"].mean()
# Out:
# 5.87790935075541

# %%
white_wine["quality"].value_counts().sort_index().plot.bar(fontsize=14,figsize=(10,5))

# %%
red_wine["quality"].value_counts().sort_index().plot.bar(fontsize=14,figsize=(10,5))

# %%
red_wine["quality"].value_counts().sort_index()
# Out:
# 3     10
# 4     53
# 5    681
# 6    638
# 7    199
# 8     18
# Name: quality, dtype: int64

# %%
plt.subplots(figsize=(15,10))
ax = plt.axes()
ax.set_title("Wine Characteristic Correlation Heatmap (Reds)")
corr = red_wine.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           cmap="Reds",fmt=".2f",annot=True)
plt.show()

# %%
plt.subplots(figsize=(15,10))
ax = plt.axes()
ax.set_title("Wine Characteristic Correlation Heatmap (Purples)")
corr = white_wine.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           cmap="Purples",annot=True,fmt='.2f')

# %%
f,ax = plt.subplots(1, 2, figsize=(14, 4))
sns.boxplot(x="quality",y='alcohol',hue='Color',data=data,ax = ax[0],palette={'R':'red',"W":'white'})
sns.boxplot(x="quality",y='density',hue='Color',data=data,ax = ax[1])

# %%
sns.boxplot(x='quality',y='pH',data=data,palette='GnBu_d')
plt.title("Boxplot of Quality and pH")
plt.show()

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
white_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %% [markdown]
# Highlights from descriptive statisct above:
#     - Mean residual sugar and total sulfur dioxide content in white wine seems to be much higher than red wine.
#     - Mean value of sulphates, fixed acidity and volatile acidity seem to be higher in red wine as compared to white wine.
#     - From all numbers, we can observe that citric acid is more present in white than red wines.
#     - In general, white wines has half concentrations of chlorides then red wines.
#     - Although in Ph the difference seems small it is interesting to note that it is slightly larger in green red wines.

# %%
def type_inf_stat_test(feature):
    F, p = f_oneway(red_wine[feature], white_wine[feature])
    if p <= 0.05:
        msg = 'Reject'
    else:
        msg = 'Acept'
    print('F Statistic: {:.2f} \tp-value: {:.3f} \tNull Hypothesis: {}'.format(F, p, msg))

# %%
from scipy.stats import f_oneway
print('ANOVA test across wine samples with different types:\n')
# - Mean residual sugar and total sulfur dioxide content in white wine seems to be much higher than red wine.
type_inf_stat_test('residual sugar')
type_inf_stat_test('total sulfur dioxide')
#- Mean value of sulphates, fixed acidity and volatile acidity seem to be higher in red wine as compared to white wine.
type_inf_stat_test('sulphates')
type_inf_stat_test('fixed acidity')
type_inf_stat_test('volatile acidity')
#- From all numbers, we can observe that citric acid is more present in white than red wines.
type_inf_stat_test('citric acid')
#- In general, white wines has half concentrations of chlorides then red wines.
type_inf_stat_test('chlorides')
#- Although in Ph the difference seems small it is interesting to note that it is slightly larger in green red wines.
type_inf_stat_test('pH')
# Out:
# ANOVA test across wine samples with different types:
#
# F Statistic: 899.77 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 6252.80 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 2021.71 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 2016.51 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 4829.32 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 236.39 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 2315.83 	p-value: 0.000 	Null Hypothesis: Reject
# F Statistic: 789.05 	p-value: 0.000 	Null Hypothesis: Reject

# %%
red_wine.drop("Color",axis=1,inplace=True)

# %%
y = red_wine['quality']
X = red_wine.drop('quality',axis=1)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
scores = cross_val_score(reg, X, y, cv=5)
scores
# Out:
# array([0.13200871, 0.31858135, 0.34955348, 0.369145  , 0.2809196 ])

# %%
from sklearn import tree
DT = tree.DecisionTreeClassifier()
scores = cross_val_score(DT, X, y, cv=5)
scores
# Out:
# array([0.496875  , 0.4625    , 0.51875   , 0.490625  , 0.42946708])

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(max_depth=5,n_estimators=200,random_state=0)
scores = cross_val_score(RF, X, y, cv=5)
scores
# Out:
# array([0.559375  , 0.559375  , 0.621875  , 0.5875    , 0.61442006])

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix,accuracy_score
y_pred = cross_val_predict(RF, X, y, cv=3)
rf_conf_matrix = confusion_matrix(y, y_pred)
rf_acc_score = accuracy_score(y, y_pred)

# %%
rf_conf_matrix
# Out:
# array([[  0,   0,   9,   1,   0,   0],
#        [  0,   0,  31,  22,   0,   0],
#        [  0,   0, 511, 169,   1,   0],
#        [  0,   0, 246, 384,   8,   0],
#        [  0,   0,  15, 156,  28,   0],
#        [  0,   0,   0,  18,   0,   0]], dtype=int64)

# %%
rf_acc_score
# Out:
# 0.5772357723577236

# %%
scores.mean()
# Out:
# 0.588509012539185

# %%
from xgboost import XGBRegressor

XGB = XGBRegressor(n_estimators=500)
scores = cross_val_score(XGB, X, y, cv=5)
scores
# Out:
# array([0.03854633, 0.19463774, 0.26277216, 0.11253117, 0.25142082])

# %%
from xgboost import XGBClassifier
XGB_classifier=XGBClassifier(n_estimators=500)
scores = cross_val_score(XGB_classifier, X, y, cv=5)
scores
# Out:
# array([0.5125    , 0.53125   , 0.521875  , 0.575     , 0.55485893])
